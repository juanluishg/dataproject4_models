# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from os import listdir
from numpy import zeros
from numpy import asarray
from numpy import savez_compressed
from pandas import read_csv
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split

# %%
# Import fastai
from fastai.vision import *

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/emotics_annotations_clean_v4.csv')
df.head()
# Out:
#                           filename  ... n_cat
# 0    COCO_val2014_000000562243.jpg  ...   2.0
# 1  COCO_train2014_000000288841.jpg  ...   1.0
# 2    COCO_val2014_000000558171.jpg  ...   3.0
# 3  COCO_train2014_000000369575.jpg  ...   2.0
# 4  COCO_train2014_000000213009.jpg  ...   2.0
#
# [5 rows x 21 columns]

# %%
df_fastai = df[["filename","folder","categories"]]
print(df_fastai)
# Out:
#                               filename  ...                          categories
# 0        COCO_val2014_000000562243.jpg  ...       Disconnection,Doubt/Confusion
# 1      COCO_train2014_000000288841.jpg  ...                        Anticipation
# 2        COCO_val2014_000000558171.jpg  ...     Engagement,Excitement,Happiness
# 3      COCO_train2014_000000369575.jpg  ...                   Aversion,Pleasure
# 4      COCO_train2014_000000213009.jpg  ...               Confidence,Excitement
# ...                                ...  ...                                 ...
# 23701  COCO_train2014_000000175368.jpg  ...                          Confidence
# 23702    COCO_val2014_000000514083.jpg  ...  Anticipation,Engagement,Excitement
# 23703       frame_k7fb824vh221kl3j.jpg  ...                          Engagement
# 23704    COCO_val2014_000000244665.jpg  ...                            Sympathy
# 23705    COCO_val2014_000000244665.jpg  ...        Anticipation,Esteem,Sympathy
#
# [23706 rows x 3 columns]

# %%
df_fastai.folder
# Out:
# 0          mscoco/images
# 1          mscoco/images
# 2          mscoco/images
# 3          mscoco/images
# 4          mscoco/images
#               ...
# 23701      mscoco/images
# 23702      mscoco/images
# 23703    framesdb/images
# 23704      mscoco/images
# 23705      mscoco/images
# Name: folder, Length: 23706, dtype: object

# %%
df_fastai['name'] = df_fastai['folder'] + '/' + df_fastai['filename']
df_fastai.drop(columns=['folder','filename'], axis=1, inplace=True)
print(df_fastai)
# Out:
#                                categories                                           name
# 0           Disconnection,Doubt/Confusion    mscoco/images/COCO_val2014_000000562243.jpg
# 1                            Anticipation  mscoco/images/COCO_train2014_000000288841.jpg
# 2         Engagement,Excitement,Happiness    mscoco/images/COCO_val2014_000000558171.jpg
# 3                       Aversion,Pleasure  mscoco/images/COCO_train2014_000000369575.jpg
# 4                   Confidence,Excitement  mscoco/images/COCO_train2014_000000213009.jpg
# ...                                   ...                                            ...
# 23701                          Confidence  mscoco/images/COCO_train2014_000000175368.jpg
# 23702  Anticipation,Engagement,Excitement    mscoco/images/COCO_val2014_000000514083.jpg
# 23703                          Engagement     framesdb/images/frame_k7fb824vh221kl3j.jpg
# 23704                            Sympathy    mscoco/images/COCO_val2014_000000244665.jpg
# 23705        Anticipation,Esteem,Sympathy    mscoco/images/COCO_val2014_000000244665.jpg
#
# [23706 rows x 2 columns]

# %%
df_fastai = df_fastai[['name','categories']]
print(df_fastai)
# Out:
#                                                 name                          categories
# 0        mscoco/images/COCO_val2014_000000562243.jpg       Disconnection,Doubt/Confusion
# 1      mscoco/images/COCO_train2014_000000288841.jpg                        Anticipation
# 2        mscoco/images/COCO_val2014_000000558171.jpg     Engagement,Excitement,Happiness
# 3      mscoco/images/COCO_train2014_000000369575.jpg                   Aversion,Pleasure
# 4      mscoco/images/COCO_train2014_000000213009.jpg               Confidence,Excitement
# ...                                              ...                                 ...
# 23701  mscoco/images/COCO_train2014_000000175368.jpg                          Confidence
# 23702    mscoco/images/COCO_val2014_000000514083.jpg  Anticipation,Engagement,Excitement
# 23703     framesdb/images/frame_k7fb824vh221kl3j.jpg                          Engagement
# 23704    mscoco/images/COCO_val2014_000000244665.jpg                            Sympathy
# 23705    mscoco/images/COCO_val2014_000000244665.jpg        Anticipation,Esteem,Sympathy
#
# [23706 rows x 2 columns]

# %%
import os.path

# %%
df_final = pd.DataFrame()
path = '/content/drive/MyDrive/EMOTIC DATASET/emotic/'
for index, row in df_fastai.iterrows():
  if os.path.isfile(path+row['name']):
    df_final = df_final.append(row)
  else:
    print('No hay na')
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na
# No hay na

# %%
df_final = df_final[['name','categories']]
df_final = df_final.reset_index()
df_final.drop(columns='index', axis=1, inplace=True)
df_final.head()
# Out:
#                                             name                          categories
# 0  mscoco/images/COCO_train2014_000000462955.jpg       Anticipation,Engagement,Peace
# 1  mscoco/images/COCO_train2014_000000144608.jpg                   Fatigue,Happiness
# 2      emodb_small/images/ebpsbjqzfhd7efh00i.jpg  Pain,Sadness,Sensitivity,Suffering
# 3      emodb_small/images/ebpsbjqzfhd7efh00i.jpg          Sadness,Suffering,Sympathy
# 4      emodb_small/images/ebpsbjqzfhd7efh00i.jpg              Fear,Sadness,Suffering

# %%
msk = np.random.rand(len(df_final)) < 0.8
df_train = df_final[msk]
df_test = df_final[~msk]
print(df_train)
# Out:
#                                                 name                          categories
# 1      mscoco/images/COCO_train2014_000000144608.jpg                   Fatigue,Happiness
# 2          emodb_small/images/ebpsbjqzfhd7efh00i.jpg  Pain,Sadness,Sensitivity,Suffering
# 3          emodb_small/images/ebpsbjqzfhd7efh00i.jpg          Sadness,Suffering,Sympathy
# 4          emodb_small/images/ebpsbjqzfhd7efh00i.jpg              Fear,Sadness,Suffering
# 5         framesdb/images/frame_k245twaqc30i5imc.jpg                          Engagement
# ...                                              ...                                 ...
# 10345      emodb_small/images/ft4hfz5gtsfl7wwi45.jpg                           Annoyance
# 10346     framesdb/images/frame_bvarawszysrqkcuf.jpg   Anticipation,Engagement,Happiness
# 10348     framesdb/images/frame_cihmig8jwxfwzifv.jpg                          Engagement
# 10349     framesdb/images/frame_cihmig8jwxfwzifv.jpg             Anticipation,Engagement
# 10350     framesdb/images/frame_k7fb824vh221kl3j.jpg                          Engagement
#
# [8329 rows x 2 columns]

# %%
print(df_test)
# Out:
#                                                 name                                         categories
# 0      mscoco/images/COCO_train2014_000000462955.jpg                      Anticipation,Engagement,Peace
# 8         framesdb/images/frame_kuxvwgw2wheq7szc.jpg               Anticipation,Disquietment,Engagement
# 24        framesdb/images/frame_7nseu023ccmqaj3p.jpg                         Engagement,Happiness,Peace
# 32        framesdb/images/frame_08cmg83x4uc6vay4.jpg                              Confidence,Engagement
# 36        framesdb/images/frame_3jwi6nrvfphi4lp6.jpg                                       Disquietment
# ...                                              ...                                                ...
# 10335     framesdb/images/frame_9l86b1cj6u0ysrq7.jpg                             Aversion,Disconnection
# 10337         ade20k/images/sun_awfqvsqstlvpdgwq.jpg                    Confidence,Excitement,Happiness
# 10342     framesdb/images/frame_fwxrk1awxnxn3osc.jpg                                   Anger,Excitement
# 10343     framesdb/images/frame_35e7vrw9jifokias.jpg  Annoyance,Doubt/Confusion,Engagement,Fear,Sadness
# 10347     framesdb/images/frame_bvarawszysrqkcuf.jpg                   Confidence,Engagement,Excitement
#
# [2022 rows x 2 columns]

# %%
df_train.to_csv('df_train')
df_test.to_csv('df_test')

# %% [markdown]
# # 1. Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_train = pd.read_csv('df_train.csv', index_col=None)
df_test = pd.read_csv('df_test.csv', index_col=None)
df_train = df_train.drop(columns='Unnamed: 0')
df_test = df_test.drop(columns='Unnamed: 0')
print(df_test)
# Out:
#                                                name                                         categories
# 0     mscoco/images/COCO_train2014_000000462955.jpg                      Anticipation,Engagement,Peace
# 1        framesdb/images/frame_kuxvwgw2wheq7szc.jpg               Anticipation,Disquietment,Engagement
# 2        framesdb/images/frame_7nseu023ccmqaj3p.jpg                         Engagement,Happiness,Peace
# 3        framesdb/images/frame_08cmg83x4uc6vay4.jpg                              Confidence,Engagement
# 4        framesdb/images/frame_3jwi6nrvfphi4lp6.jpg                                       Disquietment
# ...                                             ...                                                ...
# 2017     framesdb/images/frame_9l86b1cj6u0ysrq7.jpg                             Aversion,Disconnection
# 2018         ade20k/images/sun_awfqvsqstlvpdgwq.jpg                    Confidence,Excitement,Happiness
# 2019     framesdb/images/frame_fwxrk1awxnxn3osc.jpg                                   Anger,Excitement
# 2020     framesdb/images/frame_35e7vrw9jifokias.jpg  Annoyance,Doubt/Confusion,Engagement,Fear,Sadness
# 2021     framesdb/images/frame_bvarawszysrqkcuf.jpg                   Confidence,Engagement,Excitement
#
# [2022 rows x 2 columns]

# %%
# Load data
path = '/content/drive/MyDrive/EMOTIC DATASET/emotic/'
tfms = get_transforms(do_flip=False)
data_train = ImageDataBunch.from_df(path, df=df_train,
                              valid_pct=0.2, ds_tfms=tfms, 
                              size=224, bs=32).normalize(imagenet_stats)
data_test = ImageDataBunch.from_df(path, df=df_test, 
                              valid_pct=0.2, ds_tfms=tfms,
                              size=224, bs=32).normalize(imagenet_stats)

# %%
# Show classes
data_train.classes
# Out:
# ['Affection',
#  'Affection,Anticipation',
#  'Affection,Anticipation,Confidence,Doubt/Confusion,Engagement,Peace,Sympathy',
#  'Affection,Anticipation,Confidence,Engagement,Esteem,Excitement,Happiness,Peace,Pleasure,Sympathy',
#  'Affection,Anticipation,Confidence,Engagement,Excitement,Happiness',
#  'Affection,Anticipation,Confidence,Engagement,Excitement,Happiness,Peace,Pleasure',
#  'Affection,Anticipation,Confidence,Esteem,Happiness,Peace,Pleasure,Sympathy',
#  'Affection,Anticipation,Confidence,Happiness,Pleasure,Sensitivity',
#  'Affection,Anticipation,Engagement',
#  'Affection,Anticipation,Engagement,Excitement,Happiness',
#  'Affection,Anticipation,Engagement,Excitement,Happiness,Peace',
#  'Affection,Anticipation,Engagement,Excitement,Happiness,Pleasure',
#  'Affection,Anticipation,Engagement,Excitement,Happiness,Pleasure,Surprise',
#  'Affection,Anticipation,Engagement,Happiness',
#  'Affection,Anticipation,Engagement,Happiness,Pleasure',
#  'Affection,Anticipation,Engagement,Pleasure,Yearning',
#  'Affection,Anticipation,Esteem',
#  'Affection,Anticipation,Esteem,Sympathy',
#  'Affection,Anticipation,Excitement,Happiness,Pleasure,Sympathy',
#  'Affection,Anticipation,Happiness',
#  'Affection,Anticipation,Pleasure',
#  'Affection,Anticipation,Sympathy',
#  'Affection,Confidence',
#  'Affection,Confidence,Engagement',
#  'Affection,Confidence,Engagement,Esteem,Excitement,Pleasure,Sympathy',
#  'Affection,Confidence,Engagement,Esteem,Happiness,Peace,Pleasure',
#  'Affection,Confidence,Engagement,Esteem,Happiness,Pleasure',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Peace',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Peace,Pleasure,Sensitivity,Surprise,Sympathy',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Peace,Pleasure,Surprise',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Peace,Pleasure,Sympathy',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Pleasure',
#  'Affection,Confidence,Engagement,Excitement,Happiness,Pleasure,Sympathy',
#  'Affection,Confidence,Engagement,Excitement,Pleasure',
#  'Affection,Confidence,Engagement,Happiness',
#  'Affection,Confidence,Engagement,Happiness,Pleasure',
#  'Affection,Confidence,Engagement,Pleasure',
#  'Affection,Confidence,Esteem,Excitement,Happiness',
#  'Affection,Confidence,Esteem,Excitement,Happiness,Peace,Sympathy',
#  'Affection,Confidence,Esteem,Excitement,Happiness,Pleasure',
#  'Affection,Confidence,Esteem,Happiness,Peace,Pleasure',
#  'Affection,Confidence,Excitement,Happiness',
#  'Affection,Confidence,Excitement,Happiness,Peace',
#  'Affection,Confidence,Excitement,Happiness,Peace,Pleasure',
#  'Affection,Confidence,Excitement,Happiness,Peace,Pleasure,Surprise',
#  'Affection,Confidence,Excitement,Happiness,Pleasure',
#  'Affection,Confidence,Excitement,Happiness,Sympathy',
#  'Affection,Confidence,Happiness',
#  'Affection,Confidence,Happiness,Peace',
#  'Affection,Confidence,Happiness,Peace,Pleasure',
#  'Affection,Confidence,Happiness,Pleasure',
#  'Affection,Confidence,Pleasure',
#  'Affection,Confidence,Sympathy',
#  'Affection,Disconnection',
#  'Affection,Disconnection,Engagement,Excitement',
#  'Affection,Disconnection,Excitement,Happiness,Pleasure',
#  'Affection,Disconnection,Happiness',
#  'Affection,Disconnection,Peace',
#  'Affection,Disquietment,Doubt/Confusion,Sadness,Sensitivity,Sympathy',
#  'Affection,Disquietment,Esteem,Peace',
#  'Affection,Disquietment,Peace,Pleasure',
#  'Affection,Disquietment,Sadness',
#  'Affection,Doubt/Confusion,Engagement,Pain,Sadness,Suffering,Sympathy',
#  'Affection,Doubt/Confusion,Pleasure',
#  'Affection,Embarrassment',
#  'Affection,Embarrassment,Peace',
#  'Affection,Engagement',
#  'Affection,Engagement,Esteem',
#  'Affection,Engagement,Esteem,Happiness',
#  'Affection,Engagement,Esteem,Happiness,Peace,Pleasure',
#  'Affection,Engagement,Esteem,Happiness,Peace,Pleasure,Yearning',
#  'Affection,Engagement,Esteem,Happiness,Pleasure',
#  'Affection,Engagement,Excitement',
#  'Affection,Engagement,Excitement,Happiness',
#  'Affection,Engagement,Excitement,Happiness,Peace,Pleasure',
#  'Affection,Engagement,Excitement,Happiness,Pleasure',
#  'Affection,Engagement,Excitement,Peace,Pleasure',
#  'Affection,Engagement,Excitement,Pleasure',
#  'Affection,Engagement,Fatigue,Happiness,Peace',
#  'Affection,Engagement,Happiness',
#  'Affection,Engagement,Happiness,Peace',
#  'Affection,Engagement,Happiness,Peace,Pleasure',
#  'Affection,Engagement,Happiness,Pleasure',
#  'Affection,Engagement,Happiness,Pleasure,Surprise',
#  'Affection,Engagement,Happiness,Surprise',
#  'Affection,Engagement,Happiness,Sympathy',
#  'Affection,Engagement,Peace',
#  'Affection,Engagement,Peace,Pleasure',
#  'Affection,Engagement,Pleasure',
#  'Affection,Engagement,Sadness,Sensitivity',
#  'Affection,Engagement,Sensitivity',
#  'Affection,Engagement,Sympathy',
#  'Affection,Esteem',
#  'Affection,Esteem,Excitement,Happiness',
#  'Affection,Esteem,Excitement,Happiness,Peace,Pleasure',
#  'Affection,Esteem,Excitement,Happiness,Sympathy',
#  'Affection,Esteem,Happiness',
#  'Affection,Esteem,Happiness,Peace',
#  'Affection,Esteem,Happiness,Peace,Pleasure',
#  'Affection,Esteem,Happiness,Peace,Sympathy',
#  'Affection,Esteem,Happiness,Pleasure',
#  'Affection,Esteem,Happiness,Sympathy',
#  'Affection,Esteem,Pleasure,Sympathy',
#  'Affection,Excitement',
#  'Affection,Excitement,Happiness',
#  'Affection,Excitement,Happiness,Peace',
#  'Affection,Excitement,Happiness,Peace,Pleasure,Sympathy',
#  'Affection,Excitement,Happiness,Peace,Sensitivity,Sympathy',
#  'Affection,Excitement,Happiness,Pleasure',
#  'Affection,Excitement,Happiness,Pleasure,Surprise',
#  'Affection,Excitement,Happiness,Pleasure,Sympathy',
#  'Affection,Excitement,Happiness,Pleasure,Yearning',
#  'Affection,Excitement,Happiness,Sympathy',
#  'Affection,Fatigue',
#  'Affection,Happiness',
#  'Affection,Happiness,Peace',
#  'Affection,Happiness,Peace,Pleasure',
#  'Affection,Happiness,Peace,Pleasure,Surprise',
#  'Affection,Happiness,Peace,Pleasure,Sympathy',
#  'Affection,Happiness,Peace,Sympathy',
#  'Affection,Happiness,Pleasure',
#  'Affection,Happiness,Pleasure,Sensitivity,Sympathy',
#  'Affection,Happiness,Pleasure,Surprise',
#  'Affection,Happiness,Pleasure,Sympathy',
#  'Affection,Happiness,Sensitivity',
#  'Affection,Happiness,Surprise',
#  'Affection,Happiness,Sympathy',
#  'Affection,Peace',
#  'Affection,Peace,Pleasure',
#  'Affection,Peace,Sadness',
#  'Affection,Pleasure',
#  'Affection,Pleasure,Sympathy',
#  'Affection,Sadness,Sympathy',
#  'Anger',
#  'Anger,Annoyance',
#  'Anger,Annoyance,Anticipation,Disapproval,Doubt/Confusion',
#  'Anger,Annoyance,Anticipation,Disquietment',
#  'Anger,Annoyance,Aversion,Confidence,Disapproval,Engagement',
#  'Anger,Annoyance,Aversion,Disapproval',
#  'Anger,Annoyance,Aversion,Disapproval,Disquietment',
#  'Anger,Annoyance,Aversion,Disapproval,Disquietment,Doubt/Confusion,Suffering',
#  'Anger,Annoyance,Aversion,Disapproval,Doubt/Confusion,Pain',
#  'Anger,Annoyance,Aversion,Disapproval,Engagement',
#  'Anger,Annoyance,Aversion,Disconnection',
#  'Anger,Annoyance,Aversion,Disconnection,Disquietment',
#  'Anger,Annoyance,Aversion,Disquietment',
#  'Anger,Annoyance,Aversion,Disquietment,Pain,Suffering',
#  'Anger,Annoyance,Aversion,Engagement',
#  'Anger,Annoyance,Aversion,Suffering',
#  'Anger,Annoyance,Disapproval',
#  'Anger,Annoyance,Disapproval,Engagement',
#  'Anger,Annoyance,Disconnection',
#  'Anger,Annoyance,Disconnection,Disquietment,Doubt/Confusion,Embarrassment,Fatigue,Fear,Pain,Sadness,Suffering',
#  'Anger,Annoyance,Disconnection,Doubt/Confusion',
#  'Anger,Annoyance,Disquietment',
#  'Anger,Annoyance,Disquietment,Fear',
#  'Anger,Annoyance,Disquietment,Sensitivity,Suffering',
#  'Anger,Annoyance,Doubt/Confusion,Engagement',
#  'Anger,Annoyance,Engagement',
#  'Anger,Annoyance,Engagement,Suffering',
#  'Anger,Annoyance,Fatigue,Suffering',
#  'Anger,Annoyance,Suffering',
#  'Anger,Anticipation,Disapproval,Engagement,Pain',
#  'Anger,Aversion',
#  'Anger,Aversion,Disapproval',
#  'Anger,Aversion,Disapproval,Doubt/Confusion,Fatigue,Pain,Suffering,Surprise,Yearning',
#  'Anger,Aversion,Doubt/Confusion',
#  'Anger,Confidence',
#  'Anger,Confidence,Disapproval,Disquietment',
#  'Anger,Confidence,Excitement',
#  'Anger,Disapproval',
#  'Anger,Disapproval,Disquietment',
#  'Anger,Disapproval,Disquietment,Embarrassment',
#  'Anger,Disapproval,Disquietment,Engagement,Pain,Sensitivity,Suffering',
#  'Anger,Disapproval,Doubt/Confusion,Fatigue,Pain,Suffering,Surprise,Yearning',
#  'Anger,Disapproval,Engagement',
#  'Anger,Disapproval,Sadness',
#  'Anger,Disconnection,Doubt/Confusion',
#  'Anger,Disquietment,Engagement',
#  'Anger,Disquietment,Pain,Sensitivity,Suffering',
#  'Anger,Disquietment,Sadness',
#  'Anger,Disquietment,Sadness,Surprise',
#  'Anger,Doubt/Confusion,Fear,Surprise',
#  'Anger,Doubt/Confusion,Sadness',
#  'Anger,Embarrassment',
#  'Anger,Embarrassment,Fear',
#  'Anger,Embarrassment,Sensitivity',
#  'Anger,Engagement',
#  'Anger,Engagement,Happiness',
#  'Anger,Fear,Pain',
#  'Anger,Pain,Sadness,Sensitivity,Suffering',
#  'Anger,Sadness',
#  'Annoyance',
#  'Annoyance,Anticipation',
#  'Annoyance,Anticipation,Aversion',
#  'Annoyance,Anticipation,Confidence,Engagement',
#  'Annoyance,Anticipation,Disapproval,Doubt/Confusion,Surprise',
#  'Annoyance,Anticipation,Disapproval,Suffering',
#  'Annoyance,Anticipation,Doubt/Confusion,Pain',
#  'Annoyance,Aversion',
#  'Annoyance,Aversion,Disapproval',
#  'Annoyance,Aversion,Disapproval,Disconnection,Disquietment,Doubt/Confusion,Fatigue',
#  'Annoyance,Aversion,Disapproval,Disconnection,Doubt/Confusion,Sadness,Sensitivity',
#  'Annoyance,Aversion,Disapproval,Disquietment',
#  'Annoyance,Aversion,Disapproval,Disquietment,Suffering,Yearning',
#  'Annoyance,Aversion,Disapproval,Doubt/Confusion',
#  'Annoyance,Aversion,Fatigue,Suffering',
#  'Annoyance,Aversion,Sympathy,Yearning',
#  'Annoyance,Confidence',
#  'Annoyance,Confidence,Disapproval',
#  'Annoyance,Confidence,Disapproval,Engagement',
#  'Annoyance,Confidence,Engagement',
#  'Annoyance,Confidence,Happiness',
#  'Annoyance,Disapproval',
#  'Annoyance,Disapproval,Disconnection,Engagement',
#  'Annoyance,Disapproval,Disquietment',
#  'Annoyance,Disapproval,Disquietment,Doubt/Confusion',
#  'Annoyance,Disapproval,Disquietment,Doubt/Confusion,Suffering',
#  'Annoyance,Disapproval,Disquietment,Embarrassment',
#  'Annoyance,Disapproval,Disquietment,Suffering',
#  'Annoyance,Disapproval,Doubt/Confusion',
#  'Annoyance,Disapproval,Doubt/Confusion,Embarrassment',
#  'Annoyance,Disapproval,Doubt/Confusion,Pain',
#  'Annoyance,Disapproval,Embarrassment,Surprise',
#  'Annoyance,Disapproval,Engagement',
#  'Annoyance,Disapproval,Sadness',
#  'Annoyance,Disconnection',
#  'Annoyance,Disconnection,Disquietment,Fatigue,Sensitivity,Suffering',
#  'Annoyance,Disconnection,Fatigue',
#  'Annoyance,Disconnection,Suffering,Yearning',
#  'Annoyance,Disquietment',
#  'Annoyance,Disquietment,Doubt/Confusion',
#  'Annoyance,Disquietment,Fear',
#  'Annoyance,Disquietment,Fear,Sadness',
#  'Annoyance,Disquietment,Sympathy',
#  'Annoyance,Disquietment,Yearning',
#  'Annoyance,Doubt/Confusion',
#  'Annoyance,Doubt/Confusion,Engagement',
#  'Annoyance,Doubt/Confusion,Suffering',
#  'Annoyance,Embarrassment',
#  'Annoyance,Engagement',
#  'Annoyance,Engagement,Pain,Suffering',
#  'Annoyance,Engagement,Yearning',
#  'Annoyance,Fatigue',
#  'Annoyance,Fatigue,Sadness',
#  'Annoyance,Fatigue,Suffering',
#  'Annoyance,Pain,Sadness',
#  'Annoyance,Pleasure',
#  'Annoyance,Sadness',
#  'Annoyance,Suffering',
#  'Annoyance,Surprise',
#  'Anticipation',
#  'Anticipation,Aversion,Disapproval',
#  'Anticipation,Aversion,Doubt/Confusion',
#  'Anticipation,Aversion,Engagement',
#  'Anticipation,Aversion,Excitement,Happiness,Peace,Pleasure',
#  'Anticipation,Aversion,Fatigue',
#  'Anticipation,Confidence',
#  'Anticipation,Confidence,Disconnection',
#  'Anticipation,Confidence,Disquietment',
#  'Anticipation,Confidence,Disquietment,Esteem,Fatigue,Pain',
#  'Anticipation,Confidence,Disquietment,Fear',
#  'Anticipation,Confidence,Doubt/Confusion',
#  'Anticipation,Confidence,Doubt/Confusion,Engagement',
#  'Anticipation,Confidence,Doubt/Confusion,Engagement,Excitement,Happiness,Peace,Pleasure,Surprise',
#  'Anticipation,Confidence,Doubt/Confusion,Esteem,Excitement,Happiness',
#  'Anticipation,Confidence,Embarrassment,Engagement,Esteem,Excitement,Fatigue,Sympathy',
#  'Anticipation,Confidence,Engagement',
#  'Anticipation,Confidence,Engagement,Esteem',
#  'Anticipation,Confidence,Engagement,Esteem,Excitement',
#  'Anticipation,Confidence,Engagement,Esteem,Excitement,Happiness',
#  'Anticipation,Confidence,Engagement,Esteem,Excitement,Happiness,Pleasure',
#  'Anticipation,Confidence,Engagement,Esteem,Happiness',
#  'Anticipation,Confidence,Engagement,Excitement',
#  'Anticipation,Confidence,Engagement,Excitement,Happiness',
#  'Anticipation,Confidence,Engagement,Excitement,Happiness,Pleasure',
#  'Anticipation,Confidence,Engagement,Excitement,Peace,Pleasure',
#  'Anticipation,Confidence,Engagement,Excitement,Pleasure',
#  'Anticipation,Confidence,Engagement,Happiness',
#  'Anticipation,Confidence,Engagement,Happiness,Pleasure,Surprise',
#  'Anticipation,Confidence,Engagement,Peace',
#  'Anticipation,Confidence,Esteem',
#  'Anticipation,Confidence,Esteem,Excitement,Happiness,Pleasure',
#  'Anticipation,Confidence,Esteem,Happiness',
#  'Anticipation,Confidence,Esteem,Happiness,Peace,Pleasure,Yearning',
#  'Anticipation,Confidence,Excitement',
#  'Anticipation,Confidence,Excitement,Fear,Yearning',
#  'Anticipation,Confidence,Excitement,Happiness',
#  'Anticipation,Confidence,Excitement,Pleasure',
#  'Anticipation,Confidence,Excitement,Surprise',
#  'Anticipation,Confidence,Happiness',
#  'Anticipation,Confidence,Peace',
#  'Anticipation,Disapproval,Disconnection,Doubt/Confusion,Engagement',
#  'Anticipation,Disapproval,Disconnection,Doubt/Confusion,Excitement',
#  'Anticipation,Disapproval,Disconnection,Engagement,Fatigue',
#  'Anticipation,Disapproval,Disconnection,Surprise',
#  'Anticipation,Disapproval,Doubt/Confusion',
#  'Anticipation,Disapproval,Doubt/Confusion,Engagement',
#  'Anticipation,Disapproval,Doubt/Confusion,Surprise',
#  'Anticipation,Disapproval,Engagement',
#  'Anticipation,Disapproval,Excitement',
#  'Anticipation,Disapproval,Sadness,Sympathy',
#  'Anticipation,Disconnection',
#  'Anticipation,Disconnection,Disquietment',
#  'Anticipation,Disconnection,Disquietment,Doubt/Confusion',
#  'Anticipation,Disconnection,Doubt/Confusion',
#  'Anticipation,Disconnection,Doubt/Confusion,Fatigue',
#  'Anticipation,Disconnection,Doubt/Confusion,Surprise',
#  'Anticipation,Disconnection,Embarrassment',
#  'Anticipation,Disconnection,Engagement',
#  'Anticipation,Disconnection,Engagement,Fatigue',
#  'Anticipation,Disconnection,Fatigue',
#  'Anticipation,Disconnection,Happiness',
#  'Anticipation,Disconnection,Peace',
#  'Anticipation,Disconnection,Pleasure',
#  'Anticipation,Disconnection,Surprise',
#  'Anticipation,Disconnection,Sympathy',
#  'Anticipation,Disquietment',
#  'Anticipation,Disquietment,Doubt/Confusion,Fatigue',
#  'Anticipation,Disquietment,Engagement',
#  'Anticipation,Disquietment,Engagement,Excitement',
#  'Anticipation,Disquietment,Engagement,Excitement,Fear,Sadness,Suffering',
#  'Anticipation,Disquietment,Engagement,Sympathy',
#  'Anticipation,Doubt/Confusion',
#  'Anticipation,Doubt/Confusion,Embarrassment',
#  'Anticipation,Doubt/Confusion,Engagement',
#  'Anticipation,Doubt/Confusion,Engagement,Esteem',
#  'Anticipation,Doubt/Confusion,Engagement,Fatigue',
#  'Anticipation,Doubt/Confusion,Engagement,Happiness',
#  'Anticipation,Doubt/Confusion,Engagement,Surprise',
#  'Anticipation,Doubt/Confusion,Esteem',
#  'Anticipation,Doubt/Confusion,Excitement,Happiness',
#  'Anticipation,Doubt/Confusion,Excitement,Happiness,Peace',
#  'Anticipation,Doubt/Confusion,Excitement,Sympathy,Yearning',
#  'Anticipation,Doubt/Confusion,Fear',
#  'Anticipation,Doubt/Confusion,Happiness',
#  'Anticipation,Doubt/Confusion,Sadness',
#  'Anticipation,Doubt/Confusion,Surprise',
#  'Anticipation,Embarrassment,Happiness',
#  'Anticipation,Engagement',
#  'Anticipation,Engagement,Esteem',
#  'Anticipation,Engagement,Esteem,Excitement',
#  'Anticipation,Engagement,Esteem,Excitement,Happiness,Pleasure',
#  'Anticipation,Engagement,Esteem,Excitement,Peace,Pleasure,Yearning',
#  'Anticipation,Engagement,Esteem,Fear,Yearning',
#  'Anticipation,Engagement,Esteem,Happiness',
#  'Anticipation,Engagement,Esteem,Happiness,Pleasure',
#  'Anticipation,Engagement,Esteem,Sympathy',
#  'Anticipation,Engagement,Excitement',
#  'Anticipation,Engagement,Excitement,Happiness',
#  'Anticipation,Engagement,Excitement,Happiness,Pleasure',
#  'Anticipation,Engagement,Excitement,Happiness,Surprise',
#  'Anticipation,Engagement,Excitement,Peace,Pleasure',
#  'Anticipation,Engagement,Excitement,Pleasure',
#  'Anticipation,Engagement,Excitement,Surprise',
#  'Anticipation,Engagement,Excitement,Sympathy',
#  'Anticipation,Engagement,Fear,Peace',
#  'Anticipation,Engagement,Happiness',
#  'Anticipation,Engagement,Happiness,Peace',
#  'Anticipation,Engagement,Happiness,Pleasure',
#  'Anticipation,Engagement,Happiness,Pleasure,Yearning',
#  'Anticipation,Engagement,Happiness,Surprise',
#  'Anticipation,Engagement,Pain,Surprise',
#  'Anticipation,Engagement,Peace',
#  'Anticipation,Engagement,Pleasure',
#  'Anticipation,Engagement,Sadness',
#  'Anticipation,Engagement,Sensitivity',
#  'Anticipation,Engagement,Surprise',
#  'Anticipation,Engagement,Sympathy',
#  'Anticipation,Engagement,Yearning',
#  'Anticipation,Esteem',
#  'Anticipation,Esteem,Excitement',
#  'Anticipation,Esteem,Excitement,Happiness',
#  'Anticipation,Esteem,Excitement,Pleasure',
#  'Anticipation,Esteem,Happiness',
#  'Anticipation,Esteem,Happiness,Pleasure',
#  'Anticipation,Esteem,Pleasure,Sensitivity,Surprise',
#  'Anticipation,Excitement',
#  'Anticipation,Excitement,Fatigue',
#  'Anticipation,Excitement,Happiness',
#  'Anticipation,Excitement,Happiness,Pleasure',
#  'Anticipation,Excitement,Happiness,Pleasure,Sympathy',
#  'Anticipation,Excitement,Happiness,Sympathy',
#  'Anticipation,Excitement,Pleasure',
#  'Anticipation,Excitement,Sensitivity',
#  'Anticipation,Excitement,Surprise',
#  'Anticipation,Fatigue',
#  'Anticipation,Fatigue,Fear',
#  'Anticipation,Happiness',
#  'Anticipation,Happiness,Peace',
#  'Anticipation,Happiness,Pleasure',
#  'Anticipation,Happiness,Pleasure,Sympathy',
#  'Anticipation,Happiness,Surprise',
#  'Anticipation,Happiness,Sympathy',
#  'Anticipation,Happiness,Yearning',
#  'Anticipation,Pain',
#  'Anticipation,Pain,Suffering',
#  'Anticipation,Peace',
#  'Anticipation,Pleasure',
#  'Anticipation,Sadness',
#  'Anticipation,Surprise',
#  'Anticipation,Sympathy',
#  'Anticipation,Yearning',
#  'Aversion',
#  'Aversion,Confidence,Disconnection',
#  'Aversion,Disapproval',
#  'Aversion,Disapproval,Disconnection',
#  'Aversion,Disapproval,Disconnection,Disquietment,Doubt/Confusion,Sadness',
#  'Aversion,Disapproval,Disquietment',
#  'Aversion,Disapproval,Disquietment,Embarrassment,Surprise',
#  'Aversion,Disapproval,Disquietment,Sadness,Suffering',
#  'Aversion,Disapproval,Doubt/Confusion',
#  'Aversion,Disapproval,Sadness',
#  'Aversion,Disapproval,Sensitivity',
#  'Aversion,Disconnection',
#  'Aversion,Disconnection,Doubt/Confusion',
#  'Aversion,Disquietment,Fear,Surprise',
#  'Aversion,Disquietment,Sadness',
#  'Aversion,Doubt/Confusion,Embarrassment,Surprise',
#  'Aversion,Doubt/Confusion,Engagement',
#  'Aversion,Doubt/Confusion,Excitement,Pleasure',
#  'Aversion,Doubt/Confusion,Fear,Surprise',
#  'Aversion,Doubt/Confusion,Surprise',
#  'Aversion,Embarrassment',
#  'Aversion,Engagement,Suffering',
#  'Aversion,Engagement,Yearning',
#  'Aversion,Fatigue',
#  'Aversion,Fatigue,Sadness',
#  'Aversion,Fear,Suffering',
#  'Aversion,Sadness,Suffering',
#  'Confidence',
#  'Confidence,Disapproval',
#  'Confidence,Disapproval,Disquietment',
#  'Confidence,Disapproval,Engagement',
#  'Confidence,Disconnection',
#  'Confidence,Disconnection,Disquietment',
#  'Confidence,Disconnection,Excitement,Happiness',
#  'Confidence,Disconnection,Excitement,Happiness,Peace,Pleasure',
#  'Confidence,Disconnection,Peace',
#  'Confidence,Disconnection,Sympathy',
#  'Confidence,Doubt/Confusion',
#  'Confidence,Doubt/Confusion,Engagement',
#  'Confidence,Doubt/Confusion,Engagement,Fear,Surprise',
#  'Confidence,Doubt/Confusion,Engagement,Happiness',
#  'Confidence,Engagement',
#  'Confidence,Engagement,Esteem',
#  'Confidence,Engagement,Esteem,Excitement',
#  'Confidence,Engagement,Esteem,Excitement,Happiness,Peace',
#  'Confidence,Engagement,Esteem,Excitement,Happiness,Peace,Pleasure',
#  'Confidence,Engagement,Esteem,Excitement,Happiness,Peace,Yearning',
#  'Confidence,Engagement,Esteem,Excitement,Happiness,Pleasure',
#  'Confidence,Engagement,Esteem,Excitement,Happiness,Pleasure,Sympathy',
#  'Confidence,Engagement,Esteem,Happiness',
#  'Confidence,Engagement,Esteem,Happiness,Peace,Pleasure',
#  'Confidence,Engagement,Esteem,Pleasure',
#  'Confidence,Engagement,Esteem,Sympathy',
#  'Confidence,Engagement,Excitement',
#  'Confidence,Engagement,Excitement,Happiness',
#  'Confidence,Engagement,Excitement,Happiness,Peace',
#  'Confidence,Engagement,Excitement,Happiness,Peace,Pleasure',
#  'Confidence,Engagement,Excitement,Happiness,Pleasure',
#  'Confidence,Engagement,Excitement,Happiness,Surprise',
#  'Confidence,Engagement,Excitement,Pain',
#  'Confidence,Engagement,Excitement,Pleasure',
#  'Confidence,Engagement,Excitement,Sympathy',
#  'Confidence,Engagement,Fatigue',
#  'Confidence,Engagement,Happiness',
#  'Confidence,Engagement,Happiness,Peace',
#  'Confidence,Engagement,Happiness,Peace,Pleasure',
#  'Confidence,Engagement,Happiness,Pleasure',
#  'Confidence,Engagement,Peace',
#  'Confidence,Engagement,Pleasure',
#  'Confidence,Engagement,Surprise',
#  'Confidence,Engagement,Yearning',
#  'Confidence,Esteem',
#  'Confidence,Esteem,Excitement',
#  'Confidence,Esteem,Excitement,Happiness',
#  'Confidence,Esteem,Excitement,Happiness,Pleasure',
#  'Confidence,Esteem,Happiness',
#  'Confidence,Esteem,Happiness,Pleasure',
#  'Confidence,Esteem,Pleasure',
#  'Confidence,Esteem,Sympathy',
#  'Confidence,Excitement',
#  'Confidence,Excitement,Happiness',
#  'Confidence,Excitement,Happiness,Peace,Pleasure',
#  'Confidence,Excitement,Happiness,Pleasure',
#  'Confidence,Excitement,Happiness,Pleasure,Surprise',
#  'Confidence,Excitement,Happiness,Surprise',
#  'Confidence,Excitement,Pleasure',
#  'Confidence,Excitement,Sympathy',
#  'Confidence,Fatigue,Peace',
#  'Confidence,Fear',
#  'Confidence,Fear,Peace',
#  'Confidence,Happiness',
#  'Confidence,Happiness,Peace',
#  'Confidence,Happiness,Peace,Pleasure',
#  'Confidence,Happiness,Peace,Sympathy',
#  'Confidence,Happiness,Pleasure',
#  'Confidence,Happiness,Pleasure,Sympathy',
#  'Confidence,Happiness,Sympathy',
#  'Confidence,Pain',
#  'Confidence,Peace',
#  'Confidence,Pleasure',
#  'Confidence,Pleasure,Sensitivity',
#  'Confidence,Surprise',
#  'Disapproval',
#  'Disapproval,Disconnection',
#  'Disapproval,Disconnection,Disquietment,Doubt/Confusion',
#  'Disapproval,Disconnection,Disquietment,Doubt/Confusion,Fatigue',
#  'Disapproval,Disconnection,Doubt/Confusion,Fatigue,Pain,Suffering,Surprise,Yearning',
#  'Disapproval,Disconnection,Doubt/Confusion,Fatigue,Suffering',
#  'Disapproval,Disquietment',
#  'Disapproval,Disquietment,Doubt/Confusion',
#  'Disapproval,Disquietment,Doubt/Confusion,Fatigue,Fear,Pain,Suffering,Surprise,Yearning',
#  'Disapproval,Disquietment,Doubt/Confusion,Pain',
#  'Disapproval,Disquietment,Doubt/Confusion,Surprise',
#  'Disapproval,Disquietment,Embarrassment,Pain,Sadness,Sensitivity,Suffering',
#  'Disapproval,Disquietment,Engagement',
#  'Disapproval,Disquietment,Engagement,Excitement',
#  'Disapproval,Disquietment,Sadness,Suffering',
#  'Disapproval,Disquietment,Surprise',
#  'Disapproval,Doubt/Confusion,Engagement',
#  'Disapproval,Doubt/Confusion,Engagement,Fatigue',
#  'Disapproval,Doubt/Confusion,Engagement,Sadness',
#  'Disapproval,Doubt/Confusion,Fatigue,Happiness,Pain,Pleasure,Suffering,Surprise,Yearning',
#  'Disapproval,Doubt/Confusion,Fatigue,Pain,Pleasure,Suffering,Surprise,Yearning',
#  'Disapproval,Doubt/Confusion,Fatigue,Pain,Sadness,Suffering,Surprise,Yearning',
#  'Disapproval,Doubt/Confusion,Fatigue,Pain,Suffering,Surprise,Sympathy,Yearning',
#  'Disapproval,Doubt/Confusion,Fatigue,Pain,Suffering,Surprise,Yearning',
#  'Disapproval,Doubt/Confusion,Sadness',
#  'Disapproval,Doubt/Confusion,Suffering',
#  'Disapproval,Doubt/Confusion,Surprise',
#  'Disapproval,Embarrassment',
#  'Disapproval,Engagement',
#  'Disapproval,Engagement,Fatigue',
#  'Disapproval,Engagement,Happiness,Pleasure',
#  'Disapproval,Engagement,Pleasure',
#  'Disapproval,Engagement,Sadness',
#  'Disapproval,Engagement,Suffering',
#  'Disapproval,Engagement,Surprise',
#  'Disapproval,Fatigue',
#  'Disapproval,Fatigue,Suffering',
#  'Disapproval,Pain,Sadness,Suffering',
#  'Disapproval,Peace',
#  'Disapproval,Sadness,Suffering',
#  'Disapproval,Sadness,Sympathy',
#  'Disapproval,Sympathy',
#  'Disconnection',
#  'Disconnection,Disquietment',
#  'Disconnection,Disquietment,Doubt/Confusion',
#  'Disconnection,Disquietment,Doubt/Confusion,Fatigue,Suffering',
#  'Disconnection,Disquietment,Doubt/Confusion,Sadness',
#  'Disconnection,Disquietment,Doubt/Confusion,Sadness,Suffering',
#  'Disconnection,Disquietment,Doubt/Confusion,Sensitivity',
#  'Disconnection,Disquietment,Embarrassment,Sadness',
#  'Disconnection,Disquietment,Engagement',
#  'Disconnection,Disquietment,Engagement,Happiness',
#  'Disconnection,Disquietment,Esteem',
#  'Disconnection,Disquietment,Happiness',
#  'Disconnection,Disquietment,Sadness,Suffering',
#  'Disconnection,Disquietment,Surprise',
#  'Disconnection,Disquietment,Sympathy',
#  'Disconnection,Doubt/Confusion',
#  'Disconnection,Doubt/Confusion,Fatigue',
#  'Disconnection,Doubt/Confusion,Pain,Sadness,Suffering',
#  'Disconnection,Doubt/Confusion,Peace',
#  'Disconnection,Doubt/Confusion,Sadness',
#  'Disconnection,Doubt/Confusion,Sensitivity',
#  'Disconnection,Embarrassment',
#  'Disconnection,Engagement',
#  'Disconnection,Engagement,Excitement,Happiness,Pleasure',
#  'Disconnection,Engagement,Fatigue',
#  'Disconnection,Engagement,Happiness,Peace',
#  'Disconnection,Engagement,Peace',
#  'Disconnection,Engagement,Pleasure',
#  'Disconnection,Engagement,Pleasure,Surprise',
#  'Disconnection,Esteem',
#  'Disconnection,Esteem,Excitement,Happiness',
#  'Disconnection,Esteem,Happiness',
#  'Disconnection,Excitement',
#  'Disconnection,Excitement,Happiness',
#  'Disconnection,Fatigue',
#  'Disconnection,Fatigue,Peace',
#  'Disconnection,Fatigue,Yearning',
#  'Disconnection,Fear',
#  'Disconnection,Happiness',
#  'Disconnection,Happiness,Peace',
#  'Disconnection,Peace',
#  'Disconnection,Peace,Pleasure',
#  'Disconnection,Peace,Yearning',
#  'Disconnection,Pleasure',
#  'Disconnection,Sadness',
#  'Disconnection,Sadness,Suffering',
#  'Disconnection,Suffering',
#  'Disconnection,Surprise',
#  'Disconnection,Sympathy',
#  'Disconnection,Yearning',
#  'Disquietment',
#  'Disquietment,Doubt/Confusion',
#  'Disquietment,Doubt/Confusion,Engagement',
#  'Disquietment,Doubt/Confusion,Engagement,Surprise,Sympathy',
#  'Disquietment,Doubt/Confusion,Excitement',
#  'Disquietment,Doubt/Confusion,Fatigue',
#  'Disquietment,Doubt/Confusion,Fatigue,Sensitivity,Suffering',
#  'Disquietment,Doubt/Confusion,Fear',
#  'Disquietment,Doubt/Confusion,Fear,Sadness,Suffering',
#  'Disquietment,Doubt/Confusion,Pleasure',
#  'Disquietment,Doubt/Confusion,Sadness',
#  'Disquietment,Doubt/Confusion,Suffering',
#  'Disquietment,Embarrassment,Fear,Surprise',
#  'Disquietment,Embarrassment,Sadness',
#  'Disquietment,Engagement',
#  'Disquietment,Engagement,Fatigue',
#  'Disquietment,Engagement,Fear',
#  'Disquietment,Esteem,Sadness',
#  'Disquietment,Excitement,Fatigue',
#  'Disquietment,Fatigue',
#  'Disquietment,Fatigue,Pain,Sadness,Suffering,Sympathy',
#  'Disquietment,Fatigue,Pain,Suffering',
#  'Disquietment,Fatigue,Sadness,Suffering',
#  'Disquietment,Fear',
#  'Disquietment,Fear,Pain,Sensitivity',
#  'Disquietment,Fear,Sadness',
#  'Disquietment,Sadness',
#  'Disquietment,Sadness,Suffering',
#  'Disquietment,Sadness,Suffering,Sympathy',
#  'Disquietment,Sadness,Sympathy',
#  'Disquietment,Sadness,Yearning',
#  'Disquietment,Sensitivity,Suffering',
#  'Doubt/Confusion',
#  'Doubt/Confusion,Embarrassment,Pain,Suffering',
#  'Doubt/Confusion,Embarrassment,Sensitivity',
#  'Doubt/Confusion,Engagement',
#  'Doubt/Confusion,Engagement,Excitement',
#  'Doubt/Confusion,Engagement,Fear',
#  'Doubt/Confusion,Engagement,Happiness',
#  'Doubt/Confusion,Engagement,Peace',
#  'Doubt/Confusion,Engagement,Sadness,Sensitivity,Sympathy',
#  'Doubt/Confusion,Engagement,Surprise',
#  'Doubt/Confusion,Engagement,Yearning',
#  'Doubt/Confusion,Esteem,Fear',
#  'Doubt/Confusion,Excitement',
#  'Doubt/Confusion,Excitement,Pleasure',
#  'Doubt/Confusion,Excitement,Pleasure,Yearning',
#  'Doubt/Confusion,Excitement,Surprise',
#  'Doubt/Confusion,Fatigue',
#  'Doubt/Confusion,Fatigue,Sadness',
#  'Doubt/Confusion,Fatigue,Suffering',
#  'Doubt/Confusion,Fear',
#  'Doubt/Confusion,Fear,Peace,Yearning',
#  'Doubt/Confusion,Fear,Sensitivity,Surprise',
#  'Doubt/Confusion,Happiness',
#  'Doubt/Confusion,Peace',
#  'Doubt/Confusion,Peace,Sensitivity',
#  'Doubt/Confusion,Sadness',
#  'Doubt/Confusion,Sadness,Sensitivity',
#  'Doubt/Confusion,Sadness,Sensitivity,Suffering,Sympathy',
#  'Doubt/Confusion,Sadness,Suffering',
#  'Doubt/Confusion,Sadness,Surprise',
#  'Doubt/Confusion,Sensitivity,Surprise',
#  'Doubt/Confusion,Surprise',
#  'Embarrassment',
#  'Embarrassment,Engagement',
#  'Embarrassment,Engagement,Suffering',
#  'Embarrassment,Excitement,Happiness',
#  'Embarrassment,Fatigue,Pain',
#  'Embarrassment,Fatigue,Sympathy',
#  'Embarrassment,Fear,Pain,Sadness,Suffering',
#  'Embarrassment,Fear,Sadness',
#  'Embarrassment,Pain,Suffering',
#  'Embarrassment,Sadness',
#  'Embarrassment,Sadness,Sensitivity',
#  'Embarrassment,Sadness,Suffering',
#  'Embarrassment,Sympathy',
#  'Engagement',
#  'Engagement,Esteem',
#  'Engagement,Esteem,Excitement',
#  'Engagement,Esteem,Happiness',
#  'Engagement,Esteem,Happiness,Peace',
#  'Engagement,Esteem,Happiness,Peace,Sympathy',
#  'Engagement,Esteem,Peace',
#  'Engagement,Esteem,Peace,Sensitivity,Yearning',
#  'Engagement,Esteem,Pleasure',
#  'Engagement,Esteem,Sadness',
#  'Engagement,Esteem,Sensitivity',
#  'Engagement,Esteem,Sympathy',
#  'Engagement,Esteem,Yearning',
#  'Engagement,Excitement',
#  'Engagement,Excitement,Fear',
#  'Engagement,Excitement,Happiness',
#  'Engagement,Excitement,Happiness,Peace',
#  'Engagement,Excitement,Happiness,Peace,Pleasure',
#  'Engagement,Excitement,Happiness,Pleasure',
#  'Engagement,Excitement,Happiness,Pleasure,Surprise',
#  'Engagement,Excitement,Happiness,Pleasure,Yearning',
#  'Engagement,Excitement,Happiness,Surprise',
#  'Engagement,Excitement,Pleasure',
#  'Engagement,Excitement,Pleasure,Surprise',
#  'Engagement,Excitement,Pleasure,Yearning',
#  'Engagement,Fatigue',
#  'Engagement,Fatigue,Sadness',
#  'Engagement,Fatigue,Suffering',
#  'Engagement,Fear',
#  'Engagement,Fear,Surprise',
#  'Engagement,Happiness',
#  'Engagement,Happiness,Peace',
#  'Engagement,Happiness,Peace,Pleasure',
#  'Engagement,Happiness,Pleasure',
#  'Engagement,Happiness,Pleasure,Sensitivity',
#  'Engagement,Happiness,Pleasure,Surprise',
#  'Engagement,Happiness,Pleasure,Sympathy',
#  'Engagement,Happiness,Surprise',
#  'Engagement,Happiness,Surprise,Yearning',
#  'Engagement,Happiness,Sympathy',
#  'Engagement,Happiness,Yearning',
#  'Engagement,Pain',
#  'Engagement,Pain,Sadness,Sensitivity',
#  'Engagement,Pain,Sadness,Sympathy',
#  'Engagement,Pain,Suffering',
#  'Engagement,Peace',
#  'Engagement,Peace,Pleasure',
#  'Engagement,Peace,Sensitivity',
#  'Engagement,Peace,Surprise',
#  'Engagement,Peace,Sympathy',
#  'Engagement,Peace,Yearning',
#  'Engagement,Pleasure',
#  'Engagement,Pleasure,Sensitivity',
#  'Engagement,Pleasure,Surprise',
#  'Engagement,Sadness',
#  'Engagement,Sadness,Suffering',
#  'Engagement,Sadness,Sympathy',
#  'Engagement,Surprise',
#  'Engagement,Sympathy',
#  'Engagement,Yearning',
#  'Esteem',
#  'Esteem,Excitement',
#  'Esteem,Excitement,Happiness',
#  'Esteem,Excitement,Happiness,Pleasure',
#  'Esteem,Excitement,Happiness,Surprise',
#  'Esteem,Happiness',
#  'Esteem,Happiness,Pleasure',
#  'Esteem,Happiness,Sympathy',
#  'Esteem,Peace',
#  'Esteem,Pleasure',
#  'Esteem,Suffering',
#  'Esteem,Sympathy',
#  'Excitement',
#  'Excitement,Fear',
#  'Excitement,Fear,Surprise',
#  'Excitement,Happiness',
#  'Excitement,Happiness,Peace',
#  'Excitement,Happiness,Peace,Pleasure',
#  'Excitement,Happiness,Pleasure',
#  'Excitement,Happiness,Pleasure,Surprise',
#  'Excitement,Happiness,Surprise',
#  'Excitement,Happiness,Sympathy',
#  'Excitement,Peace',
#  'Excitement,Peace,Pleasure',
#  'Excitement,Pleasure',
#  'Excitement,Pleasure,Surprise',
#  'Excitement,Pleasure,Surprise,Yearning',
#  'Excitement,Surprise',
#  'Excitement,Yearning',
#  'Fatigue',
#  'Fatigue,Happiness',
#  'Fatigue,Pain',
#  'Fatigue,Pain,Sadness,Suffering',
#  'Fatigue,Pain,Sensitivity,Suffering',
#  'Fatigue,Pain,Suffering',
#  'Fatigue,Peace',
#  'Fatigue,Peace,Pleasure',
#  'Fatigue,Sadness',
#  'Fatigue,Sadness,Suffering',
#  'Fatigue,Sensitivity',
#  'Fatigue,Suffering',
#  'Fear',
#  'Fear,Happiness',
#  'Fear,Pain,Sadness',
#  'Fear,Pain,Sadness,Suffering',
#  'Fear,Pain,Sensitivity,Suffering',
#  'Fear,Pain,Sensitivity,Suffering,Surprise',
#  'Fear,Pain,Suffering',
#  'Fear,Pain,Surprise',
#  'Fear,Peace',
#  'Fear,Peace,Sensitivity',
#  'Fear,Sadness',
#  'Fear,Sadness,Suffering',
#  'Fear,Suffering',
#  'Fear,Surprise',
#  'Happiness',
#  'Happiness,Pain',
#  'Happiness,Peace',
#  'Happiness,Peace,Pleasure',
#  'Happiness,Peace,Pleasure,Surprise',
#  'Happiness,Peace,Pleasure,Sympathy',
#  'Happiness,Peace,Sympathy',
#  'Happiness,Pleasure',
#  'Happiness,Pleasure,Surprise',
#  'Happiness,Pleasure,Sympathy',
#  'Happiness,Pleasure,Yearning',
#  'Happiness,Sensitivity',
#  'Happiness,Sensitivity,Surprise',
#  'Happiness,Surprise',
#  'Pain',
#  'Pain,Sadness',
#  'Pain,Sadness,Sensitivity,Suffering',
#  'Pain,Sadness,Sensitivity,Sympathy',
#  'Pain,Sadness,Suffering',
#  'Pain,Sadness,Suffering,Sympathy',
#  'Pain,Sensitivity,Suffering',
#  'Pain,Suffering',
#  'Peace',
#  'Peace,Pleasure',
#  'Peace,Sadness',
#  'Peace,Sadness,Suffering',
#  'Peace,Sensitivity',
#  'Peace,Surprise',
#  'Peace,Sympathy',
#  'Pleasure',
#  'Pleasure,Surprise',
#  'Sadness',
#  'Sadness,Sensitivity',
#  'Sadness,Sensitivity,Suffering',
#  'Sadness,Sensitivity,Suffering,Sympathy',
#  'Sadness,Sensitivity,Sympathy',
#  'Sadness,Suffering',
#  'Sadness,Suffering,Sympathy',
#  'Sadness,Sympathy',
#  'Sadness,Yearning',
#  'Sensitivity',
#  'Sensitivity,Surprise,Sympathy',
#  'Sensitivity,Yearning',
#  'Suffering',
#  'Surprise',
#  'Sympathy',
#  'Yearning']

# %%
print(len(data_train.classes))
# Out:
# 836

# %%
# Show samples of data
data_train.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# # 2. Train the model

# %%
# Initialize learner
learn = cnn_learner(data_train, models.densenet201, metrics=accuracy)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer25): _DenseLayer(
#           (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer26): _DenseLayer(
#           (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer27): _DenseLayer(
#           (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer28): _DenseLayer(
#           (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer29): _DenseLayer(
#           (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer30): _DenseLayer(
#           (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer31): _DenseLayer(
#           (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer32): _DenseLayer(
#           (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer33): _DenseLayer(
#           (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer34): _DenseLayer(
#           (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer35): _DenseLayer(
#           (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer36): _DenseLayer(
#           (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer37): _DenseLayer(
#           (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer38): _DenseLayer(
#           (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer39): _DenseLayer(
#           (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer40): _DenseLayer(
#           (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer41): _DenseLayer(
#           (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer42): _DenseLayer(
#           (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer43): _DenseLayer(
#           (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer44): _DenseLayer(
#           (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer45): _DenseLayer(
#           (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer46): _DenseLayer(
#           (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer47): _DenseLayer(
#           (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer48): _DenseLayer(
#           (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(1792, 896, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1056, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(1088, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1088, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(1120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1120, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1152, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(1184, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1184, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(1216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1216, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1248, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1280, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(1312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1312, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1344, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(1376, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1376, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1408, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1440, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(1472, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1472, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(1504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1504, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(1568, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1568, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(1600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1600, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1632, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer25): _DenseLayer(
#           (norm1): BatchNorm2d(1664, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1664, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer26): _DenseLayer(
#           (norm1): BatchNorm2d(1696, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1696, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer27): _DenseLayer(
#           (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1728, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer28): _DenseLayer(
#           (norm1): BatchNorm2d(1760, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1760, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer29): _DenseLayer(
#           (norm1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1792, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer30): _DenseLayer(
#           (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1824, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer31): _DenseLayer(
#           (norm1): BatchNorm2d(1856, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1856, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer32): _DenseLayer(
#           (norm1): BatchNorm2d(1888, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1888, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(3840, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=3840, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=836, bias=True)
#   )
# )

# %%
# Configure learner with new data and freeze conv layers
learn.data = data_train
learn.freeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-27-a4568b989a21> in <module>()
#       1 # Find learning rate
# ----> 2 learn.lr_find()
#       3 learn.recorder.plot()
#
# /usr/local/lib/python3.7/dist-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, wd)
#      39     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      40     epochs = int(np.ceil(num_it/len(learn.data.train_dl))) * (num_distrib() or 1)
# ---> 41     learn.fit(epochs, start_lr, callbacks=[cb], wd=wd)
#      42
#      43 def to_fp16(learn:Learner, loss_scale:float=None, max_noskip:int=1000, dynamic:bool=True, clip:float=None,
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      89     cb_handler = CallbackHandler(callbacks, metrics)
#      90     pbar = master_bar(range(epochs))
# ---> 91     cb_handler.on_train_begin(epochs, pbar=pbar, metrics=metrics)
#      92
#      93     exception=False
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback.py in on_train_begin(self, epochs, pbar, metrics)
#     263         self.state_dict.update(dict(n_epochs=epochs, pbar=pbar, metrics=metrics))
#     264         names = [(met.name if hasattr(met, 'name') else camel2snake(met.__class__.__name__)) for met in self.metrics]
# --> 265         self('train_begin', metrics_names=names)
#     266         if self.state_dict['epoch'] != 0:
#     267             self.state_dict['pbar'].main_bar.total -= self.state_dict['epoch']
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback.py in __call__(self, cb_name, call_mets, **kwargs)
#     249         if call_mets:
#     250             for met in self.metrics: self._call_and_update(met, cb_name, **kwargs)
# --> 251         for cb in self.callbacks: self._call_and_update(cb, cb_name, **kwargs)
#     252
#     253     def set_dl(self, dl:DataLoader):
#
# /usr/local/lib/python3.7/dist-packages/fastai/callback.py in _call_and_update(self, cb, cb_name, **kwargs)
#     239     def _call_and_update(self, cb, cb_name, **kwargs)->None:
#     240         "Call `cb_name` on `cb` and update the inner state."
# --> 241         new = ifnone(getattr(cb, f'on_{cb_name}')(**self.state_dict, **kwargs), dict())
#     242         for k,v in new.items():
#     243             if k not in self.state_dict:
#
# /usr/local/lib/python3.7/dist-packages/fastai/callbacks/lr_finder.py in on_train_begin(self, pbar, **kwargs)
#      17         "Initialize optimizer and learner hyperparameters."
#      18         setattr(pbar, 'clean_on_interrupt', True)
# ---> 19         self.learn.save('tmp')
#      20         self.opt = self.learn.opt
#      21         self.opt.lr = self.sched.start
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in save(self, file, return_path, with_opt)
#     246     def save(self, file:PathLikeOrBinaryStream=None, return_path:bool=False, with_opt:bool=True):
#     247         "Save model and optimizer state (if `with_opt`) with `file` to `self.model_dir`. `file` can be file-like (file or buffer)"
# --> 248         if is_pathlike(file): self._test_writeable_path()
#     249         if rank_distrib(): return # don't save if slave proc
#     250         target = self.path/self.model_dir/f'{file}.pth' if is_pathlike(file) else file
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in _test_writeable_path(self)
#     180             tmp_file = get_tmp_file(path)
#     181         except OSError as e:
# --> 182             raise Exception(f"{e}\nCan't write to '{path}', set `learn.model_dir` attribute in Learner to a full libpath path that is writable") from None
#     183         os.remove(tmp_file)
#     184
#
# Exception: [Errno 30] Read-only file system: '/content/drive/MyDrive/EMOTIC DATASET/emotic/models'
# Can't write to '/content/drive/MyDrive/EMOTIC DATASET/emotic/models', set `learn.model_dir` attribute in Learner to a full libpath path that is writable

# %%
# Set learning rate
lr = 1e-2

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='208' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.48% [1/208 00:45<2:35:31 8.7085]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-630b855ad4fe> in <module>()
#       1 # Train 5 epochs
# ----> 2 learn.fit_one_cycle(5, max_lr=slice(lr))
#
# /usr/local/lib/python3.7/dist-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /usr/local/lib/python3.7/dist-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32     if opt is not None:
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
# ---> 34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#
# /usr/local/lib/python3.7/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:

# %%
# Save model
learn.save("score-7385")

# %%
# Unfreeze conv layers
learn.unfreeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()

# %%
# Set learning rate
lr = 1e-4

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr/100,lr))

# %%
# Save model
learn.save("score-7551")

# %% [markdown]
# # 3.   Evaluate results

# %%
# Mostrar muestras peor classificadas
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(9, figsize=(15,11))

# %%
# Show confusion matrix
interp.plot_confusion_matrix(figsize=(30,30), dpi=60)

# %%
# Show most confused classes
interp.most_confused(min_val=2)
