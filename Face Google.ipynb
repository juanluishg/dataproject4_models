# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/faceexp-comparison-data-train-public.csv", sep=",", decimal=".", header=None, error_bad_lines=False)
# Out:
# b'Skipping line 14: expected 28 fields, saw 30\nSkipping line 735: expected 28 fields, saw 30\nSkipping line 1179: expected 28 fields, saw 30\nSkipping line 1239: expected 28 fields, saw 30\nSkipping line 1243: expected 28 fields, saw 30\nSkipping line 1449: expected 28 fields, saw 30\nSkipping line 1455: expected 28 fields, saw 30\nSkipping line 1577: expected 28 fields, saw 30\nSkipping line 1675: expected 28 fields, saw 30\nSkipping line 1771: expected 28 fields, saw 30\nSkipping line 1949: expected 28 fields, saw 30\nSkipping line 2065: expected 28 fields, saw 30\nSkipping line 2071: expected 28 fields, saw 30\nSkipping line 2542: expected 28 fields, saw 30\nSkipping line 2637: expected 28 fields, saw 30\nSkipping line 2789: expected 28 fields, saw 30\nSkipping line 2792: expected 28 fields, saw 30\nSkipping line 3226: expected 28 fields, saw 30\nSkipping line 3253: expected 28 fields, saw 30\nSkipping line 3397: expected 28 fields, saw 30\nSkipping line 3411: expected 28 fields,
# ...

# %%
df.shape
# Out:
# (446536, 28)

# %%
df.head()
# Out:
#                                                   0         1         2   \
# 0  http://farm5.staticflickr.com/4108/5185055338_...  0.142578  0.266602
# 1  http://farm5.staticflickr.com/4108/5185055338_...  0.142578  0.266602
# 2  http://farm5.staticflickr.com/4108/5185055338_...  0.142578  0.266602
# 3  http://farm5.staticflickr.com/4108/5185055338_...  0.718750  0.826172
# 4  http://farm5.staticflickr.com/4108/5185055338_...  0.718750  0.826172
#
#          3         4                                                  5   \
# 0  0.065421  0.297508  http://farm3.staticflickr.com/2127/5765052001_...
# 1  0.065421  0.297508  http://farm4.staticflickr.com/3543/3387356856_...
# 2  0.065421  0.297508  http://farm4.staticflickr.com/3858/14540292875...
# 3  0.194704  0.394081  http://farm4.staticflickr.com/3875/14501588548...
# 4  0.194704  0.394081  http://farm6.staticflickr.com/5143/5693754914_...
#
#          6         7         8         9   ...      18  19      20  21  \
# ...

# %%
df.tail()
# Out:
#                                                        0         1        2   \
# 446531  http://farm6.staticflickr.com/5212/5527101846_...  0.232404  0.64409
# 446532  http://farm6.staticflickr.com/5212/5527101846_...  0.232404  0.64409
# 446533  http://farm6.staticflickr.com/5212/5527101846_...  0.232404  0.64409
# 446534  http://farm6.staticflickr.com/5212/5527101846_...  0.232404  0.64409
# 446535  http://farm6.staticflickr.com/5212/5527101846_...  0.232404  0.64409
#
#          3         4                                                  5   \
# 446531  0.0  0.263672  http://farm6.staticflickr.com/5543/9123075383_...
# 446532  0.0  0.263672  http://farm4.staticflickr.com/3707/9051161725_...
# 446533  0.0  0.263672  http://farm5.staticflickr.com/4064/4377775761_...
# 446534  0.0  0.263672  http://farm2.staticflickr.com/1250/817137222_4...
# 446535  0.0  0.263672  http://farm8.staticflickr.com/7374/9663184882_...
#
# ...

# %%
df[0][0]
# Out:
# 'http://farm5.staticflickr.com/4108/5185055338_1dec873bf3_b.jpg'

# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=a655545543584ffe8220f43b36a91d216a7a88276164944049112649c69ed7b9
#   Stored in directory: c:\users\juanl\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\juanl\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
df[0][0]
# Out:
# 0.142578

# %%
# %time
import wget

for i, d in df.iterrows():
    # Set up the image URL
    image_url = df[0][i]
    
    # Use wget download method to download specified image url.
    image_filename = wget.download(image_url, 'raw_data/google')
    
    image_url = df[5][i]
    image_filename = wget.download(image_url, 'raw_data/google')
# Out:
# Wall time: 0 ns
# -1 / unknown
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-19-c0dfcc665bdd> in <module>
#      10
#      11     image_url = df[5][i]
# ---> 12     image_filename = wget.download(image_url, 'raw_data/google')
#
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# c:\users\juanl\appdata\local\programs\python\python38\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...
